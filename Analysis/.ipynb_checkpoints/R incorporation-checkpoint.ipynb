# %%
import os
os.environ['R_HOME'] = "C:\\Users\\veoni\\anaconda3\\Lib\\R"
import rpy2
from rpy2 import robjects

from rpy2.robjects.packages import importr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from rpy2.robjects import r, pandas2ri

pandas2ri.activate()

# These will let us use R packages:
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

import numpy as np
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import pandas as pd
import glob
import statistics
import pingouin as pg
import scikit_posthocs as sp
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.anova import AnovaRM

# imports the base module for R.
base = importr("base")
 
# imports the utils package for R.
utils = importr("utils")

tidyverse = importr("tidyverse")
ggpubr = importr("ggpubr")
rstatix = importr("rstatix")
ez = importr("ez")


# Convert pandas.DataFrames to R dataframes automatically.
pandas2ri.activate()

# %%
df = pd.read_csv("DF_cleaned.csv")
df_correct =  df[df['acc'] == True]
df_correct
# Out:
#        Unnamed: 0  pt_num  trial_nbr block_number        rt   soa   acc  \
# 0               1       1          2      Block 1  1.147471  0.10  True
# 1               3       1          4      Block 1  1.216055  0.10  True
# 2               4       1          5      Block 1  2.355647  0.10  True
# 3               5       1          6      Block 1  1.640664  0.05  True
# 4               6       1          7      Block 1  2.079118  0.10  True
# ...           ...     ...        ...          ...       ...   ...   ...
# 41290       43190       9       1431     Block 10  0.661540  0.10  True
# 41291       43191       9       1432     Block 10  0.728739  0.10  True
# 41293       43193       9       1434     Block 10  1.120992  0.05  True
# 41295       43195       9       1436     Block 10  0.614821  0.05  True
# 41296       43196       9       1437     Block 10  1.254312  0.05  True
#
#        category choiced_category difficulty   size_occl pressed_key  \
# ...

# %%
r_df_correct=pandas2ri.DataFrame(df_correct)
pandas2ri.activate()
#r_dataframe = pandas2ri.py2ri(df_correct)
# Perform Two-Way ANOVA with R to check sphericity assumption thoroughly
#robjects.r(ez.ezANOVA(data= df_correct,dv = "rt",wid = "pt_num", within = ('difficulty','soa')))
#r_df_correct = pandas2ri.py2ri(df_correct)
#robjects.r("res.aov_1 <- ezANOVA(data = df_correct,dv = rt,wid = pt_num, within = c(difficulty,soa))")
r_df_correct = pandas2ri.py2rpy_pandasdataframe(df_correct)
robjects.r("r_df_correct <-  convert_as_factor(pt_num, difficulty,soa)")

#ez.ezANOVA(data = r_df_correct, dv = "rt", wid = "pt_num", within = ["difficulty", "soa"])

robjects.r(ez.ezANOVA(data = r_df_correct, dv = "rt",wid = "pt_num", within = 'difficulty'))
# Out:
# R[write to console]: Error in tbl_vars_dispatch(x) : object 'pt_num' not found
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24504\1589245109.py in <cell line: 9>()
#       7 #robjects.r("res.aov_1 <- ezANOVA(data = df_correct,dv = rt,wid = pt_num, within = c(difficulty,soa))")
#       8 r_df_correct = pandas2ri.py2rpy_pandasdataframe(df_correct)
# ----> 9 robjects.r("r_df_correct <-  convert_as_factor(pt_num, difficulty,soa)")
#      10
#      11 #ez.ezANOVA(data = r_df_correct, dv = "rt", wid = "pt_num", within = ["difficulty", "soa"])
#
# ~\anaconda3\lib\site-packages\rpy2\robjects\__init__.py in __call__(self, string)
#     457     def __call__(self, string):
#     458         p = rinterface.parse(string)
# --> 459         res = self.eval(p)
#     460         return conversion.get_conversion().rpy2py(res)
#     461
#
# ...

# %%
print(r_df_correct)
